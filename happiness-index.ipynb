# %% [markdown]
# # World Happiness Index

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
happy_15 = pd.read_csv('2015.csv')
happy_16 = pd.read_csv('2016.csv')
happy_17 = pd.read_csv('2017.csv')

# %%
happy_15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happy_16.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
happy_17.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
happy_16.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
happy_16[happy_16.Region == 'Sub-Saharan Africa']
# Out:
#                  Country              Region  Happiness Rank  Happiness Score  \
# 65             Mauritius  Sub-Saharan Africa              66            5.648
# 75               Somalia  Sub-Saharan Africa              76            5.440
# 96     Somaliland Region  Sub-Saharan Africa              97            5.057
# 102              Nigeria  Sub-Saharan Africa             103            4.875
# 105               Zambia  Sub-Saharan Africa             106            4.795
# 110         Sierra Leone  Sub-Saharan Africa             111            4.635
# 112              Namibia  Sub-Saharan Africa             113            4.574
# 113             Cameroon  Sub-Saharan Africa             114            4.513
# 114             Ethiopia  Sub-Saharan Africa             115            4.508
# 115         South Africa  Sub-Saharan Africa             116            4.459
# 121                Kenya  Sub-Saharan Africa             122            4.356
# ...

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 12
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %%
fig, ax = plt.subplots()
happy_16.groupby('Region')['Happiness Score'].mean().plot(kind='bar')
ax.legend()

# %%
gdp_16 = happy_16['Economy (GDP per Capita)']
life_16 = happy_16['Health (Life Expectancy)']
index_16 = happy_16['Happiness Score']
dystopia_16 = happy_16['Dystopia Residual']
free_16 = happy_16['Freedom']
trust_16 = happy_16['Trust (Government Corruption)']

# %%
plt.scatter(life_16, gdp_16)
plt.scatter(gdp_16, index_16)

# %%
fig, ax = plt.subplots()
plt.scatter(life_16, gdp_16, c=index_16)
ax.legend()

# %%
plt.scatter(dystopia_16, index_16)

# %%
free_17 = happy_17['Freedom']
trust_17 = happy_17['Trust..Government.Corruption.']

# %%
free_16.plot(kind='line', color='red', alpha=0.6)
free_17.plot(kind='line', color='green', alpha=0.6)

# %%
trust_16.plot(kind='line', color='red', alpha=0.6)
trust_17.plot(kind='line', color='green', alpha=0.6)

# %%
trust = happy_16.groupby('Region')['Trust (Government Corruption)'].mean()
dystopia = happy_16.groupby('Region')['Dystopia Residual'].mean()

# %%
fig, ax = plt.subplots()
trust.plot(kind='bar')
ax.legend()

# %%
fig, ax = plt.subplots()
dystopia.plot(kind='bar')
ax.legend()
